# %%
with open("GDS5420.soft","r") as f:
    with open("GDS5420.txt","w") as output:
        flg = 0
        for line in f:
            if line == "!dataset_table_end\n":
                break
            
            if flg == 1:
                output.write(line)
            
            if line == "!dataset_table_begin\n":
                print("found!")
                flg = 1
# Out:
# found!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_table("GDS5420.txt").drop("ID_REF",axis = 1).set_index("IDENTIFIER")
dataset = dataset.replace(np.nan,0)
dataset.tail()
# Out:
#             GSM1296094  GSM1296119  GSM1296076  GSM1296092  GSM1296103  \
# IDENTIFIER
# --Control       246.98      116.58       67.58       77.57      322.75
# --Control       741.22      255.36      113.52      206.69      856.64
# --Control        93.88       81.73       64.70       33.04       78.10
# --Control         0.00        6.17        0.00        0.95        0.00
# --Control         0.00        4.85        0.00        4.99        0.00
#
#             GSM1296078  GSM1296107  GSM1296109  GSM1296080  GSM1296090  ...  \
# IDENTIFIER                                                              ...
# --Control        67.26      160.04      243.27      320.72       69.22  ...
# --Control       102.21      426.42      755.95      827.17      195.53  ...
# --Control       103.14       57.65       57.59       46.89       39.90  ...
# --Control         6.38        0.00        0.00        0.00        2.33  ...
# ...

# %%
logged_data = dataset.apply(np.log2)
logged_data = logged_data.replace(-np.inf,0)
logged_data = logged_data.drop(index=["--Control","STAT1"])
logged_data.tail()
# Out:
#             GSM1296094  GSM1296119  GSM1296076  GSM1296092  GSM1296103  \
# IDENTIFIER
# ACTB         10.015875   11.899161   11.594488   11.119544   11.130641
# ACTB         12.309846   12.871724   12.800360   12.635584   13.009034
# GAPDH        13.565780   13.292969   13.369393   13.311833   13.570093
# GAPDH        12.616448   13.014202   12.768701   12.740219   12.990503
# GAPDH        12.966168   12.855435   12.635813   12.772009   13.312330
#
#             GSM1296078  GSM1296107  GSM1296109  GSM1296080  GSM1296090  ...  \
# IDENTIFIER                                                              ...
# ACTB         11.204693   11.862482   11.409455    8.625745   11.184944  ...
# ACTB         12.512797   12.945405   12.741385   12.275447   12.705693  ...
# GAPDH        13.143138   13.373314   13.389188   13.700386   13.079418  ...
# GAPDH        12.641146   12.946175   12.654813   11.442912   12.747012  ...
# ...

# %%
import collections
l = logged_data.index.values.tolist()
c = collections.Counter(l)
print(len(c))
# Out:
# 30804

# %%
df_corr = logged_data.T.corr()　#5-10min
df_corr.head()
# Out:
# IDENTIFIER   MIR4640      RFC2     HSPA6      PAX8    GUCA1A   MIR5193  \
# IDENTIFIER
# MIR4640     1.000000 -0.006501 -0.037708 -0.218786 -0.001993  0.666299
# RFC2       -0.006501  1.000000  0.381578  0.135027  0.055112 -0.063681
# HSPA6      -0.037708  0.381578  1.000000 -0.035618 -0.118957  0.187556
# PAX8       -0.218786  0.135027 -0.035618  1.000000  0.062392 -0.176275
# GUCA1A     -0.001993  0.055112 -0.118957  0.062392  1.000000  0.116902
#
# IDENTIFIER      THRA    PTPN21      CCL5    CYP2E1  ...     MEX3D    EPS8L1  \
# IDENTIFIER                                          ...
# MIR4640     0.009696 -0.185167 -0.067669 -0.018796  ... -0.591915  0.322870
# RFC2        0.058656  0.358823 -0.073760  0.408006  ... -0.203953  0.365050
# HSPA6       0.247251  0.219682  0.271133  0.255285  ... -0.011560  0.054381
# PAX8        0.180864  0.106197  0.002073 -0.066773  ...  0.172534 -0.089769
# GUCA1A     -0.061498 -0.005252  0.194316 -0.075222  ... -0.042130  0.054424
#
# ...

# %%
df_corr.where(df_corr > 0.9, True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-51-141c1d150d6b> in <module>
# ----> 1 df_corr.where(df_corr > 0.9, True)
#
# ~/.pyenv/versions/3.7.0/envs/attention/lib/python3.7/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9003         other = com.apply_if_callable(other, self)
#    9004         return self._where(
# -> 9005             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9006         )
#    9007
#
# ~/.pyenv/versions/3.7.0/envs/attention/lib/python3.7/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8742         cond = com.apply_if_callable(cond, self)
#    8743         if isinstance(cond, NDFrame):
# -> 8744             cond, _ = cond.align(self, join="right", broadcast_axis=1)
# ...
